# %% [markdown]
# ### This Notebook is for getting the lats/longs of a bus route

# %%
import pandas as pd
import geopandas as gpd


pd.set_option('display.max_columns', None) ### This line makes all the columns display, rather than ellipses shorten

# %%
### import files 

king_county_bus_stops = pd.read_csv("C:/Users/aaron/Fun Mapping Work/Data/Bus_Stop_Data/Transit_Stops_for_King_County_Metro___transitstop_point.csv")

king_county_bus_lines = gpd.read_file("C:/Users/aaron/Fun Mapping Work/Data/Bus_Stop_Data/Transit_Routes_for_King_County_Metro___transitroute_line")

# %%
king_county_bus_stops
# Out:
#                X          Y  OBJECTID  CHANGE_NUM  MINOR_CHANGE_NUM  \
# 0      1348971.0   74764.20         1         159                 5
# 1      1348962.0   73925.91         2         159                 5
# 2      1309012.0  176035.70         3         159                 5
# 3      1348943.0   72311.21         4         159                 5
# 4      1348413.0   71214.21         5         159                 5
# ...          ...        ...       ...         ...               ...
# 29825  1259503.0  209367.10     29826         159                 4
# 29826  1259490.0  208862.60     29827         159                 4
# 29827  1254089.0  243082.80     29828         159                 4
# 29828  1254075.0  242415.00     29829         159                 4
# 29829  1254060.0  241778.40     29830         159                 4
#
#       ACCESSIBILITY_DECAL ACCESSORY_SIGN  STOP_ID  TRANS_LINK_ID STOP_STATUS  \
# 0                     YES            NaN    99478          79301         ACT
# 1                     YES            NaN    99479          67925         ACT
# 2                     UNK        Unknown    99480         288185         CLO
# 3                     YES            NaN    99481         235293         ACT
# 4                     YES     Off engine    99482         235295         ACT
# ...                   ...            ...      ...            ...         ...
# 29825                 YES            NaN    22830         167619         ACT
# 29826                 YES            NaN    22840         167620         CLO
# 29827                 YES            NaN    24710         128551         ACT
# 29828                 YES            NaN    24720          18744         ACT
# 29829                 UNK            NaN    24730         116612         CLO
#
#       STOP_TYPE AUTH_CODE AUTH_NAME TRF_DISTRICT_CODE AWNING BAY_CODE  \
# 0           REG       ENU  Enumclaw                SE     NO      NaN
# 1           REG       ENU  Enumclaw                SE     NO      NaN
# 2           REG       UNK   Unknown                SE    UNK      NaN
# 3           REG       ENU  Enumclaw                SE     NO      NaN
# 4            RL       ENU  Enumclaw                SE     NO      NaN
# ...         ...       ...       ...               ...    ...      ...
# 29825       REG       SEA   Seattle                SW     NO      NaN
# 29826       REG       SEA   Seattle                SW     NO      NaN
# 29827       REG       SEA   Seattle                CB     NO      NaN
# 29828       REG       SEA   Seattle                CB     NO      NaN
# 29829       REG       SEA   Seattle                CB     NO      NaN
#
#       BEARING_CODE BIKE_RACK CURB  CURB_HEIGHT_FRONTDOOR    CURBPAINT  \
# 0                S        NO  UNK                    0.0  YelRed-Stop
# 1                S        NO  UNK                    0.0  YelRed-Stop
# 2                E        NO  UNK                    0.0      Unknown
# 3                S        NO  UNK                    0.0  YelRed-Stop
# 4                S        NO  UNK                    0.0          NaN
# ...            ...       ...  ...                    ...          ...
# 29825            S        NO  YES                    6.0  YelRed-Stop
# 29826            S        NO  UNK                    0.0      Unknown
# 29827            S        NO  UNK                    4.0  YelRed-Stop
# 29828            S        NO  UNK                    0.0      Unknown
# 29829            S        NO  UNK                    NaN      Unknown
#
#        CURBPAINTLENGTH CURRENT_NEXT_CODE            CF_CROSS_STREETNAME  \
# 0                 10.0           CURRENT                  Roosevelt Ave
# 1                 10.0           CURRENT               Christianson Ave
# 2                  0.0           CURRENT                Maplewood Pl SE
# 3                 10.0           CURRENT                     Warner Ave
# 4                  0.0           CURRENT                  McDougall Ave
# ...                ...               ...                            ...
# 29825            150.0        IN SERVICE                  SW Avalon Way
# 29826            150.0        IN SERVICE  West Seattle Golf Course AcRd
# 29827             80.0        IN SERVICE                   W Thurman St
# 29828             30.0        IN SERVICE                   W Emerson St
# 29829             60.0        IN SERVICE                   W Ruffner St
#
#        CF_DIST_FROM_INTERSECTION CF_INTERSECTION_LOCCODE  \
# 0                          175.0                      FS
# 1                          125.0                      NS
# 2                          116.0                      NS
# 3                           38.0                      NS
# 4                          320.0                      NM
# ...                          ...                     ...
# 29825                      170.0                      FS
# 29826                       30.1                      NS
# 29827                       92.2                      FS
# 29828                      100.1                      FS
# 29829                       77.0                      FS
#
#                  DATE_CREATED      DATE_LAST_MODIFIED             DB_MOD_DATE  \
# 0      1997/09/20 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 1      1997/09/20 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 2      1986/06/28 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 3      1997/09/20 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 4      1997/09/20 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# ...                       ...                     ...                     ...
# 29825  1982/09/15 04:30:00+00  2025/10/07 20:32:00+00  2025/10/11 00:00:00+00
# 29826  1981/03/15 04:30:00+00  2025/10/07 20:32:00+00  2025/10/11 00:00:00+00
# 29827  1960/01/01 04:30:00+00  2025/10/07 20:32:00+00  2025/10/11 00:00:00+00
# 29828  1960/01/01 04:30:00+00  2025/10/07 20:32:00+00  2025/10/11 00:00:00+00
# 29829  1960/01/01 04:30:00+00  2025/10/07 20:32:00+00  2025/10/11 00:00:00+00
#
#        DIST_FROM_INTERSECTION     EFFECTIVE_BEGINDATE  FARE_ZONE  \
# 0                       175.0  2020/04/28 00:00:00+00         40
# 1                       125.0  2019/09/21 00:00:00+00         40
# 2                       116.0  1996/01/30 00:00:00+00         24
# 3                        38.0  2019/09/21 00:00:00+00         40
# 4                       320.0  2020/04/28 00:00:00+00         40
# ...                       ...                     ...        ...
# 29825                   170.0  2019/01/22 00:00:00+00          1
# 29826                    30.1  2016/09/01 00:00:00+00          1
# 29827                    92.2  1960/01/01 00:00:00+00          1
# 29828                   100.1  1960/01/01 00:00:00+00          1
# 29829                    77.0  2008/01/12 00:00:00+00          1
#
#       FRDOORLANDING  FRDOORSIDEWALKWIDTH       HASTUS_CROSS_STREET_NAME  \
# 0           Unknown                  0.0                  Roosevelt Ave
# 1           Unknown                  0.0               Christianson Ave
# 2           Unknown                  0.0                Maplewood Pl SE
# 3           Unknown                  0.0                     Warner Ave
# 4           Unknown                  0.0                  McDougall Ave
# ...             ...                  ...                            ...
# 29825    ADA Access                  0.0                  SW Avalon Way
# 29826       Unknown                  0.0  West Seattle Golf Course AcRd
# 29827       Unknown                  0.0                   W Thurman St
# 29828       Unknown                  0.0                   W Emerson St
# 29829       Unknown                  NaN                   W Ruffner St
#
#       IMT_CONNECTORLIST IN_SERVICE_FLAG INFOSIGN_ANCHOR INFOSIGN  \
# 0                   NaN               N             NaN      NaN
# 1                   NaN               N             NaN      NaN
# 2                   NaN               N             UNK  Unknown
# 3                   NaN               N             NaN      NaN
# 4                   NaN               N             NaN      NaN
# ...                 ...             ...             ...      ...
# 29825               NaN               Y             NaN      NaN
# 29826               NaN               Y             NaN      NaN
# 29827               NaN               Y             NaN      NaN
# 29828               NaN               Y             NaN      NaN
# 29829               NaN               Y             NaN      NaN
#
#       INTERSECTION_LOC JURISDICTION KCM_MANAGED_EQUIPMENT     XCOORD  \
# 0             Far side          ENU                   YES  1348995.9
# 1            Near side          ENU                   YES  1348986.9
# 2            Near side          RNT                   UNK  1309024.0
# 3            Near side          ENU                   YES  1348967.6
# 4          Near middle          ENU                   YES  1348438.3
# ...                ...          ...                   ...        ...
# 29825         Far side          SEA                   YES  1259527.6
# 29826        Near side          SEA                   YES  1259515.3
# 29827         Far side          SEA                   YES  1254114.1
# 29828         Far side          SEA                   YES  1254099.6
# 29829         Far side          SEA                   UNK  1254085.2
#
#        XCOORD_OFFSET    YCOORD  YCOORD_OFFSET  ZIPCODE       ROUTE_LIST  \
# 0            1348971   74764.2       74764.20    98022              915
# 1            1348962   73925.6       73925.91    98022              915
# 2            1309012  176057.7      176035.70    98058              NaN
# 3            1348943   72310.9       72311.21    98022              915
# 4            1348413   71213.9       71214.21    98022              915
# ...              ...       ...            ...      ...              ...
# 29825        1259503  209366.5      209367.10    98126  21 21E 50 773 C
# 29826        1259490  208862.0      208862.60    98126              NaN
# 29827        1254089  243082.2      243082.80    98199               24
# 29828        1254075  242414.4      242415.00    98199               24
# 29829        1254060  241777.8      241778.40    98199              NaN
#
#                   ON_STREET_NAME   ROUTESIGN ROUTESIGN_OWNER  \
# 0                    Semanski St  A1 <=2 rts             KCM
# 1                    Semanski St  A1 <=2 rts             KCM
# 2               Maple Valley Hwy     Unknown             UNK
# 3                    Semanski St  A1 <=2 rts             KCM
# 4      Enumclaw High School AcRd  A1 <=2 rts             KCM
# ...                          ...         ...             ...
# 29825                35th Ave SW  A2 <=6 rts             KCM
# 29826                35th Ave SW  A2 <=6 rts             KCM
# 29827                 34th Ave W  A1 <=2 rts             KCM
# 29828                 34th Ave W  A1 <=2 rts             KCM
# 29829                 34th Ave W     Unknown             KCM
#
#       SIGN_MOUNTING_DIR   SIGNPOST SIGNPOST_ANCHOR SCHEDULE_HOLDER  \
# 0                Toward  2in metal     Cncrt-earth             NaN
# 1                  Away  2in metal     Cncrt-earth             NaN
# 2                   NaN    Unknown         Unknown             UNK
# 3                Toward  2in metal     Cncrt-earth             NaN
# 4                Toward      Light            Band             NaN
# ...                 ...        ...             ...             ...
# 29825              Away        NaN        Concrete          Double
# 29826              Away        NaN        Concrete          Double
# 29827              Away  2in metal    Cncrt-asphlt             NaN
# 29828              Away  2in metal         Unknown          Single
# 29829              Away  2in metal         Unknown             NaN
#
#        NUM_SHELTERS     GISOBJID  DISPLACEMENT
# 0                 0       9347.0         175.0
# 1                 0       9348.0        2842.0
# 2                 0  100012459.0        6794.0
# 3                 0       9349.0          38.0
# 4                 0       9350.0          54.0
# ...             ...          ...           ...
# 29825             1       1946.0          58.0
# 29826             0  100000050.0        2981.9
# 29827             0       2094.0        6508.8
# 29828             1       2095.0        6497.9
# 29829             0          NaN        6494.0
#
# [29830 rows x 58 columns]

# %%
## trim a bit
king_county_bus_stops = king_county_bus_stops[king_county_bus_stops['CURRENT_NEXT_CODE'] == 'CURRENT']

# %%
king_county_bus_stops
# Out:
#                X          Y  OBJECTID  CHANGE_NUM  MINOR_CHANGE_NUM  \
# 0      1348971.0   74764.20         1         159                 5
# 1      1348962.0   73925.91         2         159                 5
# 2      1309012.0  176035.70         3         159                 5
# 3      1348943.0   72311.21         4         159                 5
# 4      1348413.0   71214.21         5         159                 5
# ...          ...        ...       ...         ...               ...
# 27245  1277948.0  157743.70     27246         159                 5
# 27246  1277858.0  157441.20     27247         159                 5
# 27247  1278566.0  145564.10     27248         159                 5
# 27248  1278448.0  145443.10     27249         159                 5
# 27249  1277545.0  134361.30     27250         159                 5
#
#       ACCESSIBILITY_DECAL ACCESSORY_SIGN  STOP_ID  TRANS_LINK_ID STOP_STATUS  \
# 0                     YES            NaN    99478          79301         ACT
# 1                     YES            NaN    99479          67925         ACT
# 2                     UNK        Unknown    99480         288185         CLO
# 3                     YES            NaN    99481         235293         ACT
# 4                     YES     Off engine    99482         235295         ACT
# ...                   ...            ...      ...            ...         ...
# 27245                 YES        Unknown    99913         362990         ACT
# 27246                 YES        Unknown    99914         362989         ACT
# 27247                 UNK        Unknown    99915         384032         ACT
# 27248                 UNK        Unknown    99916         384039         ACT
# 27249                 UNK        Unknown    99917         384031         ACT
#
#       STOP_TYPE AUTH_CODE      AUTH_NAME TRF_DISTRICT_CODE AWNING BAY_CODE  \
# 0           REG       ENU       Enumclaw                SE     NO      NaN
# 1           REG       ENU       Enumclaw                SE     NO      NaN
# 2           REG       UNK        Unknown                SE    UNK      NaN
# 3           REG       ENU       Enumclaw                SE     NO      NaN
# 4            RL       ENU       Enumclaw                SE     NO      NaN
# ...         ...       ...            ...               ...    ...      ...
# 27245        RL        ST  Sound Transit                SE     NO      NaN
# 27246        RL        ST  Sound Transit                SE     NO      NaN
# 27247       REG       UNK        Unknown                SE    UNK      NaN
# 27248       REG       UNK        Unknown                SE    UNK      NaN
# 27249       REG       UNK        Unknown                SE    UNK      NaN
#
#       BEARING_CODE BIKE_RACK CURB  CURB_HEIGHT_FRONTDOOR    CURBPAINT  \
# 0                S        NO  UNK                    0.0  YelRed-Stop
# 1                S        NO  UNK                    0.0  YelRed-Stop
# 2                E        NO  UNK                    0.0      Unknown
# 3                S        NO  UNK                    0.0  YelRed-Stop
# 4                S        NO  UNK                    0.0          NaN
# ...            ...       ...  ...                    ...          ...
# 27245            N        NO  UNK                    0.0          NaN
# 27246            S        NO  UNK                    0.0          NaN
# 27247            N        NO  UNK                    0.0      Unknown
# 27248            S        NO  UNK                    0.0      Unknown
# 27249            N        NO  UNK                    0.0      Unknown
#
#        CURBPAINTLENGTH CURRENT_NEXT_CODE CF_CROSS_STREETNAME  \
# 0                 10.0           CURRENT       Roosevelt Ave
# 1                 10.0           CURRENT    Christianson Ave
# 2                  0.0           CURRENT     Maplewood Pl SE
# 3                 10.0           CURRENT          Warner Ave
# 4                  0.0           CURRENT       McDougall Ave
# ...                ...               ...                 ...
# 27245              0.0           CURRENT          S 200th St
# 27246              0.0           CURRENT          S 200th St
# 27247              0.0           CURRENT  Kent Des Moines Rd
# 27248              0.0           CURRENT  Kent Des Moines Rd
# 27249              0.0           CURRENT          S 272nd St
#
#        CF_DIST_FROM_INTERSECTION CF_INTERSECTION_LOCCODE  \
# 0                          175.0                      FS
# 1                          125.0                      NS
# 2                          116.0                      NS
# 3                           38.0                      NS
# 4                          320.0                      NM
# ...                          ...                     ...
# 27245                      105.0                      FS
# 27246                      215.0                      FS
# 27247                     1000.0                      FS
# 27248                     1100.0                      FS
# 27249                      400.0                      NS
#
#                  DATE_CREATED      DATE_LAST_MODIFIED             DB_MOD_DATE  \
# 0      1997/09/20 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 1      1997/09/20 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 2      1986/06/28 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 3      1997/09/20 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 4      1997/09/20 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# ...                       ...                     ...                     ...
# 27245  2016/06/29 09:07:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 27246  2016/06/29 08:59:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 27247  2023/11/15 09:19:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 27248  2023/11/15 09:20:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 27249  2023/11/15 09:24:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
#
#        DIST_FROM_INTERSECTION     EFFECTIVE_BEGINDATE  FARE_ZONE  \
# 0                       175.0  2020/04/28 00:00:00+00         40
# 1                       125.0  2019/09/21 00:00:00+00         40
# 2                       116.0  1996/01/30 00:00:00+00         24
# 3                        38.0  2019/09/21 00:00:00+00         40
# 4                       320.0  2020/04/28 00:00:00+00         40
# ...                       ...                     ...        ...
# 27245                   105.0  2022/10/19 00:00:00+00         83
# 27246                   215.0  2022/10/19 00:00:00+00         83
# 27247                  1000.0  2023/11/16 00:00:00+00         24
# 27248                  1100.0  2023/11/16 00:00:00+00         24
# 27249                   400.0  2023/11/16 00:00:00+00         24
#
#       FRDOORLANDING  FRDOORSIDEWALKWIDTH HASTUS_CROSS_STREET_NAME  \
# 0           Unknown                  0.0            Roosevelt Ave
# 1           Unknown                  0.0         Christianson Ave
# 2           Unknown                  0.0          Maplewood Pl SE
# 3           Unknown                  0.0               Warner Ave
# 4           Unknown                  0.0            McDougall Ave
# ...             ...                  ...                      ...
# 27245       Unknown                  0.0               S 200th St
# 27246       Unknown                  0.0               S 200th St
# 27247       Unknown                  0.0       Kent Des Moines Rd
# 27248       Unknown                  0.0       Kent Des Moines Rd
# 27249       Unknown                  0.0               S 272nd St
#
#       IMT_CONNECTORLIST IN_SERVICE_FLAG INFOSIGN_ANCHOR INFOSIGN  \
# 0                   NaN               N             NaN      NaN
# 1                   NaN               N             NaN      NaN
# 2                   NaN               N             UNK  Unknown
# 3                   NaN               N             NaN      NaN
# 4                   NaN               N             NaN      NaN
# ...                 ...             ...             ...      ...
# 27245               NaN               N             NaN      NaN
# 27246               NaN               N             NaN      NaN
# 27247               NaN               N             UNK  Unknown
# 27248               NaN               N             UNK  Unknown
# 27249               NaN               N             UNK  Unknown
#
#       INTERSECTION_LOC JURISDICTION KCM_MANAGED_EQUIPMENT     XCOORD  \
# 0             Far side          ENU                   YES  1348995.9
# 1            Near side          ENU                   YES  1348986.9
# 2            Near side          RNT                   UNK  1309024.0
# 3            Near side          ENU                   YES  1348967.6
# 4          Near middle          ENU                   YES  1348438.3
# ...                ...          ...                   ...        ...
# 27245         Far side          STC                    NO  1277923.4
# 27246         Far side          STC                    NO  1277882.7
# 27247      At cross st          KNT                   UNK  1278541.7
# 27248      At cross st          KNT                   UNK  1278472.9
# 27249      At cross st          KNT                   UNK  1277521.2
#
#        XCOORD_OFFSET    YCOORD  YCOORD_OFFSET  ZIPCODE ROUTE_LIST  \
# 0            1348971   74764.2       74764.20    98022        915
# 1            1348962   73925.6       73925.91    98022        915
# 2            1309012  176057.7      176035.70    98058        NaN
# 3            1348943   72310.9       72311.21    98022        915
# 4            1348413   71213.9       71214.21    98022        915
# ...              ...       ...            ...      ...        ...
# 27245        1277948  157743.4      157743.70    98188        599
# 27246        1277858  157441.2      157441.20    98198        599
# 27247        1278566  145568.8      145564.10    98032        599
# 27248        1278448  145438.4      145443.10    98032        599
# 27249        1277545  134370.3      134361.30    98032        599
#
#                   ON_STREET_NAME   ROUTESIGN ROUTESIGN_OWNER  \
# 0                    Semanski St  A1 <=2 rts             KCM
# 1                    Semanski St  A1 <=2 rts             KCM
# 2               Maple Valley Hwy     Unknown             UNK
# 3                    Semanski St  A1 <=2 rts             KCM
# 4      Enumclaw High School AcRd  A1 <=2 rts             KCM
# ...                          ...         ...             ...
# 27245              ST Light Rail   Non-Metro              ST
# 27246              ST Light Rail   Non-Metro              ST
# 27247              ST Light Rail     Unknown             UNK
# 27248              ST Light Rail     Unknown             UNK
# 27249              ST Light Rail     Unknown             UNK
#
#       SIGN_MOUNTING_DIR   SIGNPOST SIGNPOST_ANCHOR SCHEDULE_HOLDER  \
# 0                Toward  2in metal     Cncrt-earth             NaN
# 1                  Away  2in metal     Cncrt-earth             NaN
# 2                   NaN    Unknown         Unknown             UNK
# 3                Toward  2in metal     Cncrt-earth             NaN
# 4                Toward      Light            Band             NaN
# ...                 ...        ...             ...             ...
# 27245               NaN        NaN             NaN             NaN
# 27246               NaN        NaN             NaN             NaN
# 27247               NaN    Unknown         Unknown             UNK
# 27248               NaN    Unknown         Unknown             UNK
# 27249               NaN    Unknown         Unknown             UNK
#
#        NUM_SHELTERS     GISOBJID  DISPLACEMENT
# 0                 0       9347.0         175.0
# 1                 0       9348.0        2842.0
# 2                 0  100012459.0        6794.0
# 3                 0       9349.0          38.0
# 4                 0       9350.0          54.0
# ...             ...          ...           ...
# 27245             0  100012324.0       14093.9
# 27246             0  100012306.0       14162.3
# 27247             0  100016403.0       10345.0
# 27248             0  100016402.0         799.4
# 27249             0  100016401.0       12719.9
#
# [14916 rows x 58 columns]

# %%
stops_gdf = gpd.GeoDataFrame(
    king_county_bus_stops, geometry = gpd.points_from_xy(king_county_bus_stops.X, king_county_bus_stops.Y), crs = "EPSG:2926")

# %%
route_8_line = king_county_bus_lines[king_county_bus_lines['ROUTE_NUM'] == 8]

king_county_bus_lines.head()
# Out:
#    OBJECTID  CHANGE_NUM  MINOR_CHAN  CURRENT_NE IN_SERVICE  ROUTE_ID  \
# 0         1         159           0  IN SERVICE          Y    100004
# 1         2         159           0  IN SERVICE          Y    100005
# 2         3         159           0  IN SERVICE          Y    100006
# 3         4         159           0  IN SERVICE          Y    100009
# 4         5         159           0  IN SERVICE          Y    100011
#
#   LOCAL_EXPR  ROUTE_NUM     SHAPE_Leng  \
# 0          L        105   35162.641853
# 1          L        106  100130.985905
# 2          L        107  111990.287908
# 3          L         11   33540.618256
# 4          L        111  238565.135087
#
#                                             geometry
# 0  MULTILINESTRING ((1301756.7 178887, 1301685.5 ...
# 1  MULTILINESTRING ((1298237.9 178658.2, 1298228 ...
# 2  MULTILINESTRING ((1300214.1 178025, 1300523.6 ...
# 3  MULTILINESTRING ((1272084.8 227987, 1271969.6 ...
# 4  MULTILINESTRING ((1323408.6 175386.1, 1323414 ...

# %%
#route_8_line.plot()

# %%
type (route_8_line)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
### make a spatial join to get all the stops within a close distance of the 8 line.

stops_near_8 = gpd.sjoin(stops_gdf, route_8_line, how = 'inner', predicate='dwithin', distance=50)

# %%
### I'm done with this BS i am just going to manaully get the stop numbers and get their lat longs/

route_8_stop_numbers = [2672, 2180, 2200, 2244, 2245, 2250, 2255, 2260, 2262, 2264, 29268, 29270, 29277, 29273, 29274, 29275, 
                        29276, 12378, 12380, 43706, 43710, 43712, 43714, 43716, 43720, 27335, 12630, 12010, 43724,
                        43728, 12479, 12487, 12484, 12486, 8402] # length 29

# %%
route_8_eastbound = stops_gdf[stops_gdf['STOP_ID'].isin(route_8_stop_numbers)]

# %%
route_8_eastbound.explore(column = 'STOP_ID', tooltip = "STOP_ID")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_388e36383a3d2e2cddc37dfce58efe09 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_388e36383a3d2e2cddc37dfce58efe09&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_388e36383a3d2e2cddc37dfce58efe09 = L.map(
#                 &quot;map_388e36383a3d2e2cddc37dfce58efe09&quot;,
#                 {
#                     center: [47.60083128673309, -122.32653351896832],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_388e36383a3d2e2cddc37dfce58efe09);
#
#
#
#
#
#             var tile_layer_b30812ac7470bca7db85c4c9138ab8de = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b30812ac7470bca7db85c4c9138ab8de.addTo(map_388e36383a3d2e2cddc37dfce58efe09);
#
#
#             map_388e36383a3d2e2cddc37dfce58efe09.fitBounds(
#                 [[47.5775954567337, -122.35686022308631], [47.62406711673248, -122.29620681485034]],
#                 {}
#             );
#
#
#         function geo_json_4fca37818931c85026e2140be02fc4fe_styler(feature) {
#             switch(feature.id) {
#                 case &quot;19008&quot;: case &quot;19010&quot;: case &quot;19013&quot;: case &quot;19014&quot;: case &quot;19015&quot;: case &quot;19058&quot;: case &quot;19059&quot;:
#                     return {&quot;color&quot;: &quot;#2fb47c&quot;, &quot;fillColor&quot;: &quot;#2fb47c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;19102&quot;: case &quot;19103&quot;: case &quot;19796&quot;: case &quot;19797&quot;: case &quot;19800&quot;: case &quot;19801&quot;: case &quot;19802&quot;: case &quot;20263&quot;: case &quot;20266&quot;:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;19230&quot;: case &quot;22242&quot;: case &quot;22244&quot;: case &quot;22245&quot;:
#                     return {&quot;color&quot;: &quot;#3b518b&quot;, &quot;fillColor&quot;: &quot;#3b518b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;19436&quot;: case &quot;19845&quot;:
#                     return {&quot;color&quot;: &quot;#3c508b&quot;, &quot;fillColor&quot;: &quot;#3c508b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;20009&quot;:
#                     return {&quot;color&quot;: &quot;#23a983&quot;, &quot;fillColor&quot;: &quot;#23a983&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;20448&quot;:
#                     return {&quot;color&quot;: &quot;#3d4e8a&quot;, &quot;fillColor&quot;: &quot;#3d4e8a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;21630&quot;:
#                     return {&quot;color&quot;: &quot;#3b528b&quot;, &quot;fillColor&quot;: &quot;#3b528b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;22207&quot;:
#                     return {&quot;color&quot;: &quot;#463480&quot;, &quot;fillColor&quot;: &quot;#463480&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;22217&quot;:
#                     return {&quot;color&quot;: &quot;#450559&quot;, &quot;fillColor&quot;: &quot;#450559&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#fde725&quot;, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_4fca37818931c85026e2140be02fc4fe_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_4fca37818931c85026e2140be02fc4fe_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quo

# %%
route_8_eastbound_sorted = route_8_eastbound.sort_values(by="STOP_ID", key=lambda column: column.map(lambda e: route_8_stop_numbers.index(e)), inplace=True)
# Out:
# C:\Users\aaron\AppData\Local\Temp\ipykernel_21040\3234542823.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   route_8_eastbound_sorted = route_8_eastbound.sort_values(by="STOP_ID", key=lambda column: column.map(lambda e: route_8_stop_numbers.index(e)), inplace=True)

# %%
route_8_eastbound.head(20)
# Out:
#                X         Y  OBJECTID  CHANGE_NUM  MINOR_CHANGE_NUM  \
# 22217  1264751.0  231357.1     22218         159                 5
# 20263  1264731.0  230545.2     20264         159                 5
# 20266  1264706.0  229608.8     20267         159                 5
# 19796  1265967.0  229311.0     19797         159                 5
# 19797  1266914.0  229287.0     19798         159                 5
# 19800  1268227.0  229253.1     19801         159                 5
# 19801  1269293.0  229225.9     19802         159                 5
# 19802  1270194.0  229207.4     19803         159                 5
# 19102  1271092.0  229177.3     19103         159                 5
# 19103  1271954.0  229160.1     19104         159                 5
# 19008  1272588.0  229403.3     19009         159                 5
# 19010  1273680.0  229643.0     19011         159                 5
# 19059  1274678.0  229634.7     19060         159                 5
# 19013  1275512.0  229627.7     19014         159                 5
# 19014  1276014.0  229812.2     19015         159                 5
# 19015  1276878.0  229792.1     19016         159                 5
# 19058  1277946.0  229670.6     19059         159                 5
# 19436  1278844.0  230001.0     19437         159                 5
# 19845  1279359.0  230499.0     19846         159                 5
# 6857   1279667.0  229592.6      6858         159                 5
#
#       ACCESSIBILITY_DECAL ACCESSORY_SIGN  STOP_ID  TRANS_LINK_ID STOP_STATUS  \
# 22217                 YES            NaN     2672             72         ACT
# 20263                 YES            NaN     2180          78596         ACT
# 20266                 YES            NaN     2200          97411         ACT
# 19796                 YES            NaN     2244           1918         ACT
# 19797                 YES            NaN     2245         190877         ACT
# 19800                 YES            NaN     2250          23479         ACT
# 19801                 YES            NaN     2255         188559         ACT
# 19802                 YES        Unknown     2260          13269         ACT
# 19102                 YES            NaN     2262         188561         ACT
# 19103                 YES        Unknown     2264         143848         ACT
# 19008                 YES            NaN    29268         191342         ACT
# 19010                 YES            NaN    29270          70030         ACT
# 19059                 YES            NaN    29277         191360         ACT
# 19013                 YES            NaN    29273         113570         ACT
# 19014                 YES            NaN    29274         191461         ACT
# 19015                 YES            NaN    29275         146354         ACT
# 19058                 YES            NaN    29276          75732         ACT
# 19436                 YES            NaN    12378         126187         CLO
# 19845                 YES            NaN    12380         156990         CLO
# 6857                  YES            NaN    43706          84392         ACT
#
#       STOP_TYPE AUTH_CODE AUTH_NAME TRF_DISTRICT_CODE AWNING BAY_CODE  \
# 22217       REG       SEA   Seattle                CB     NO      NaN
# 20263       REG       SEA   Seattle                CB     NO      NaN
# 20266       REG       SEA   Seattle                CB     NO      NaN
# 19796       REG       SEA   Seattle                CB     NO      NaN
# 19797       REG       SEA   Seattle                CB     NO      NaN
# 19800       REG       SEA   Seattle                CB     NO      NaN
# 19801       REG       SEA   Seattle                CB     NO      NaN
# 19802       REG       SEA   Seattle                CB     NO      NaN
# 19102       REG       SEA   Seattle                CB     NO      NaN
# 19103       REG       SEA   Seattle                SC    UNK      NaN
# 19008       REG       SEA   Seattle                SC     NO      NaN
# 19010       REG       SEA   Seattle                SC    YES        1
# 19059       REG       SEA   Seattle                SC     NO      NaN
# 19013       REG       SEA   Seattle                SC     NO      NaN
# 19014       REG       SEA   Seattle                SC     NO      NaN
# 19015       REG       SEA   Seattle                SC     NO      NaN
# 19058       REG       SEA   Seattle                SC     NO      NaN
# 19436       REG       SEA   Seattle                SC     NO      NaN
# 19845       REG       SEA   Seattle                SC     NO      NaN
# 6857        REG       SEA   Seattle                SC     NO      NaN
#
#       BEARING_CODE BIKE_RACK CURB  CURB_HEIGHT_FRONTDOOR    CURBPAINT  \
# 22217            S        NO  YES                    6.0  YelRed-Stop
# 20263            S        NO  UNK                    0.0      Unknown
# 20266            S        NO  UNK                    0.0  YelRed-Stop
# 19796            E        NO  YES                    6.0  YelRed-Stop
# 19797            E        NO  UNK                    0.0      Unknown
# 19800            E        NO  UNK                    0.0      Unknown
# 19801            E        NO  UNK                    0.0      Unknown
# 19802            E        NO  UNK                    0.0      Unknown
# 19102            E        NO  UNK                    0.0      Unknown
# 19103            E        NO  YES                    6.0  YelRed-Stop
# 19008            E        NO  UNK                    0.0      Unknown
# 19010            E        NO  YES                    6.0  YelRed-Stop
# 19059            E        NO  YES                    6.0  YelRed-Stop
# 19013            E        NO  UNK                    0.0      Unknown
# 19014            E        NO  UNK                    0.0      Unknown
# 19015            E        NO  UNK                    0.0      Unknown
# 19058            E        NO  UNK                    0.0      Unknown
# 19436            E        NO  UNK                    0.0      Unknown
# 19845            E        NO  YES                    6.0  YelRed-Stop
# 6857             S        NO  UNK                    0.0      Unknown
#
#        CURBPAINTLENGTH CURRENT_NEXT_CODE CF_CROSS_STREETNAME  \
# 22217            120.0           CURRENT         W Mercer St
# 20263             90.0           CURRENT       W Harrison St
# 20266            127.0           CURRENT           W John St
# 19796             10.0           CURRENT             2nd Ave
# 19797             10.0           CURRENT            Cedar St
# 19800             10.0           CURRENT          Dexter Ave
# 19801             10.0           CURRENT        Westlake Ave
# 19802             10.0           CURRENT        Fairview Ave
# 19102             10.0           CURRENT          Stewart St
# 19103             10.0           CURRENT         Melrose Ave
# 19008             60.0           CURRENT        Summit Ave E
# 19010            125.0           CURRENT          Broadway E
# 19059             10.0           CURRENT          12th Ave E
# 19013             80.0           CURRENT          15th Ave E
# 19014             80.0           CURRENT          16th Ave E
# 19015             80.0           CURRENT          19th Ave E
# 19058             90.0           CURRENT          22nd Ave E
# 19436             75.0           CURRENT          25th Ave E
# 19845             90.0           CURRENT          27th Ave E
# 6857              60.0           CURRENT           E John St
#
#        CF_DIST_FROM_INTERSECTION CF_INTERSECTION_LOCCODE  \
# 22217                      190.0                      FS
# 20263                       99.6                      FS
# 20266                      184.7                      FM
# 19796                      280.0                      FS
# 19797                      100.0                      NS
# 19800                       35.0                      NS
# 19801                       65.0                      FS
# 19802                       65.0                      NS
# 19102                       19.0                      NS
# 19103                      105.0                      FS
# 19008                      130.0                      FS
# 19010                      100.0                      FS
# 19059                      125.0                      FS
# 19013                       79.5                      NS
# 19014                       90.0                      FS
# 19015                       40.1                      NS
# 19058                      109.9                      FS
# 19436                       84.9                      FS
# 19845                       27.5                      NS
# 6857                        58.1                      FS
#
#                  DATE_CREATED      DATE_LAST_MODIFIED             DB_MOD_DATE  \
# 22217  1997/09/20 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 20263  1979/05/15 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 20266  1981/03/15 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 19796  2013/04/23 10:18:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 19797  1995/02/11 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 19800  1995/02/11 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 19801  1995/02/11 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 19802  1995/02/11 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 19102  1995/02/11 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 19103  2023/03/23 15:11:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 19008  1960/01/01 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 19010  1981/09/15 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 19059  1981/03/15 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 19013  1960/01/01 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 19014  1960/01/01 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 19015  1982/09/15 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 19058  1981/09/15 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 19436  1981/03/15 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 19845  1981/03/15 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
# 6857   1988/09/17 04:30:00+00  2025/10/07 20:32:00+00  2025/10/27 00:00:00+00
#
#        DIST_FROM_INTERSECTION     EFFECTIVE_BEGINDATE  FARE_ZONE  \
# 22217                   190.0  2020/11/04 00:00:00+00          1
# 20263                    99.6  2017/12/02 00:00:00+00          1
# 20266                   184.7  2024/07/10 00:00:00+00          1
# 19796                   280.0  2023/01/25 00:00:00+00          1
# 19797                   100.0  1995/02/11 00:00:00+00          1
# 19800                    35.0  1995/02/11 00:00:00+00          1
# 19801                    65.0  1995/02/11 00:00:00+00          1
# 19802                    65.0  2015/08/22 00:00:00+00          1
# 19102                    19.0  1995/02/11 00:00:00+00          1
# 19103                   105.0  2023/03/24 00:00:00+00          1
# 19008                   130.0  1960/01/01 00:00:00+00          1
# 19010                   100.0  2024/09/14 00:00:00+00          1
# 19059                   125.0  2011/05/14 00:00:00+00          1
# 19013                    79.5  2019/10/23 00:00:00+00          1
# 19014                    90.0  1960/01/01 00:00:00+00          1
# 19015                    40.1  1982/09/15 00:00:00+00          1
# 19058                   109.9  1981/09/15 00:00:00+00          1
# 19436                    84.9  2024/09/14 00:00:00+00          1
# 19845                    27.5  2024/09/14 00:00:00+00          1
# 6857                     58.1  1997/09/20 00:00:00+00          1
#
#       FRDOORLANDING  FRDOORSIDEWALKWIDTH HASTUS_CROSS_STREET_NAME  \
# 22217       Unknown                  0.0              W Mercer St
# 20263       Unknown                  0.0            W Harrison St
# 20266       Unknown                  0.0                W John St
# 19796    ADA Access                  0.0                  2nd Ave
# 19797       Unknown                  0.0                 Cedar St
# 19800       Unknown                  0.0               Dexter Ave
# 19801       Unknown                  0.0             Westlake Ave
# 19802    ADA Access                  0.0             Fairview Ave
# 19102       Unknown                  0.0               Stewart St
# 19103       Unknown                  0.0              Melrose Ave
# 19008       Unknown                  0.0             Summit Ave E
# 19010    ADA Access                  0.0               Broadway E
# 19059    ADA Access                 72.0               12th Ave E
# 19013       Unknown                  0.0               15th Ave E
# 19014       Unknown                  0.0               16th Ave E
# 19015       Unknown                  0.0               19th Ave E
# 19058       Unknown                  0.0               22nd Ave E
# 19436       Unknown                  0.0               25th Ave E
# 19845    ADA Access                  0.0               27th Ave E
# 6857        Unknown                  0.0                E John St
#
#       IMT_CONNECTORLIST IN_SERVICE_FLAG INFOSIGN_ANCHOR INFOSIGN  \
# 22217               NaN               N             NaN  Default
# 20263               NaN               N             NaN  Default
# 20266               NaN               N             NaN  Default
# 19796               NaN               N             NaN  Default
# 19797               NaN               N             NaN      NaN
# 19800               NaN               N             NaN      NaN
# 19801               NaN               N             NaN      NaN
# 19802               NaN               N         Unknown  Unknown
# 19102               NaN               N             NaN      NaN
# 19103               NaN               N             UNK  Unknown
# 19008               NaN               N             NaN      NaN
# 19010              LTRL               N             NaN      NaN
# 19059               NaN               N             NaN      NaN
# 19013               NaN               N             NaN      NaN
# 19014               NaN               N             NaN      NaN
# 19015               NaN               N             NaN      NaN
# 19058               NaN               N             NaN      NaN
# 19436               NaN               N             NaN      NaN
# 19845               NaN               N             NaN      NaN
# 6857                NaN               N             NaN      NaN
#
#       INTERSECTION_LOC JURISDICTION KCM_MANAGED_EQUIPMENT     XCOORD  \
# 22217         Far side          SEA                   YES  1264775.7
# 20263         Far side          SEA                   YES  1264755.8
# 20266       Far middle          SEA                   YES  1264730.7
# 19796         Far side          SEA                   YES  1265967.4
# 19797        Near side          SEA                   YES  1266913.9
# 19800        Near side          SEA                   YES  1268227.3
# 19801         Far side          SEA                   YES  1269293.1
# 19802        Near side          SEA                   YES  1270194.4
# 19102        Near side          SEA                   YES  1271093.5
# 19103         Far side          SEA                   YES  1271954.3
# 19008         Far side          SEA                   YES  1272569.3
# 19010         Far side          SEA                   YES  1273680.5
# 19059         Far side          SEA                   YES  1274678.2
# 19013        Near side          SEA                   YES  1275512.0
# 19014         Far side          SEA                   YES  1276014.5
# 19015        Near side          SEA                   YES  1276878.8
# 19058         Far side          SEA                   YES  1277946.8
# 19436         Far side          SEA                   YES  1278826.9
# 19845        Near side          SEA                   YES  1279342.0
# 6857          Far side          SEA                   YES  1279691.6
#
#        XCOORD_OFFSET    YCOORD  YCOORD_OFFSET  ZIPCODE          ROUTE_LIST  \
# 22217        1264751  231356.2       231357.1    98109      1 13 2 32N 8 D
# 20263        1264731  230544.6       230545.2    98109         1 13 2 32 8
# 20266        1264706  229607.9       229608.8    98109          1 13 2 8 D
# 19796        1265967  229336.0       229311.0    98109  1 13 17E 2 24 33 8
# 19797        1266914  229312.0       229287.0    98109                   8
# 19800        1268227  229278.1       229253.1    98109                   8
# 19801        1269293  229250.9       229225.9    98109                   8
# 19802        1270194  229232.4       229207.4    98109                   8
# 19102        1271092  229202.3       229177.3    98101                   8
# 19103        1271954  229185.1       229160.1    98102                   8
# 19008        1272588  229419.7       229403.3    98102                11 8
# 19010        1273680  229668.0       229643.0    98102             11 43 8
# 19059        1274678  229659.7       229634.7    98102             11 43 8
# 19013        1275512  229652.7       229627.7    98112             11 43 8
# 19014        1276014  229837.2       229812.2    98112             11 43 8
# 19015        1276878  229817.1       229792.1    98112             11 43 8
# 19058        1277946  229695.6       229670.6    98112             11 43 8
# 19436        1278844  230018.9       230001.0    98112                 NaN
# 19845        1279359  230517.0       230499.0    98112                 NaN
# 6857         1279667  229591.7       229592.6    98112                   8
#
#                ON_STREET_NAME    ROUTESIGN ROUTESIGN_OWNER SIGN_MOUNTING_DIR  \
# 22217        Queen Anne Ave N  B1 <=12 rts             KCM               NaN
# 20263        Queen Anne Ave N   A2 <=6 rts             KCM             Flush
# 20266        Queen Anne Ave N  B1 <=12 rts             KCM              Away
# 19796               Denny Way  B1 <=12 rts             KCM               NaN
# 19797               Denny Way   A1 <=2 rts             KCM              Away
# 19800               Denny Way   A1 <=2 rts             KCM              Away
# 19801               Denny Way   A1 <=2 rts             KCM              Away
# 19802               Denny Way   A1 <=2 rts             KCM              Away
# 19102               Denny Way   A1 <=2 rts             KCM              Away
# 19103             E Denny Way   A1 <=2 rts             KCM              Away
# 19008             E Olive Way   A1 <=2 rts             KCM              Away
# 19010               E John St   A2 <=6 rts             KCM            Toward
# 19059               E John St   A2 <=6 rts             KCM            Toward
# 19013               E John St   A2 <=6 rts             KCM            Toward
# 19014             E Thomas St   A2 <=6 rts             KCM              Away
# 19015             E Thomas St   A2 <=6 rts             KCM              Away
# 19058               E John St   A2 <=6 rts             KCM              Away
# 19436            E Madison St   A1 <=2 rts             KCM              Away
# 19845            E Madison St   A1 <=2 rts             KCM              Away
# 6857   Martin L King Jr Way E   A1 <=2 rts             KCM              Away
#
#         SIGNPOST SIGNPOST_ANCHOR SCHEDULE_HOLDER  NUM_SHELTERS     GISOBJID  \
# 22217        NaN         Unknown             NaN             0        271.0
# 20263        NaN        Concrete             NaN             1        215.0
# 20266  2in metal      Base plate          Double             2        216.0
# 19796        NaN             NaN             NaN             2  100012447.0
# 19797  2in metal        Concrete          Double             1        224.0
# 19800  2in metal        Concrete          Single             1        226.0
# 19801  2in metal        Concrete          Single             1        227.0
# 19802  2in metal        Concrete         Unknown             1        228.0
# 19102    Utility            Band          Single             1        229.0
# 19103  2in metal      Base plate             UNK             0  100016348.0
# 19008  2in metal         Unknown          Double             2       2520.0
# 19010  2in metal      Base plate             NaN             1       2522.0
# 19059  2in metal      Base plate             NaN             1  100000834.0
# 19013  2in metal         Unknown          Double             1       2525.0
# 19014  2in metal         Unknown          Double             1       2526.0
# 19015  2in metal         Unknown          Double             1       2527.0
# 19058  2in metal        Concrete          Double             1       2528.0
# 19436  2in metal         Unknown             NaN             0       1076.0
# 19845  2in metal      Base plate             NaN             0       1077.0
# 6857   2in metal     Cncrt-earth          Single             0       3657.0
#
#        DISPLACEMENT                  geometry
# 22217        4567.0  POINT (1264751 231357.1)
# 20263        4154.4  POINT (1264731 230545.2)
# 20266        4169.3  POINT (1264706 229608.8)
# 19796         280.0    POINT (1265967 229311)
# 19797        1423.3    POINT (1266914 229287)
# 19800        3029.0  POINT (1268227 229253.1)
# 19801          65.0  POINT (1269293 229225.9)
# 19802        2447.0  POINT (1270194 229207.4)
# 19102          32.9  POINT (1271092 229177.3)
# 19103         105.0  POINT (1271954 229160.1)
# 19008        2262.2  POINT (1272588 229403.3)
# 19010         100.0    POINT (1273680 229643)
# 19059        1576.5  POINT (1274678 229634.7)
# 19013        1855.5  POINT (1275512 229627.7)
# 19014        1545.3  POINT (1276014 229812.2)
# 19015        1289.9  POINT (1276878 229792.1)
# 19058         109.9  POINT (1277946 229670.6)
# 19436          84.9    POINT (1278844 230001)
# 19845        2966.5    POINT (1279359 230499)
# 6857         4600.9  POINT (1279667 229592.6)

# %%
### reprojecting to 4326 to get the lats/longs

route_8_projected = route_8_eastbound.to_crs(4326)

# %%
point_list = route_8_projected.geometry

# %%
for point in point_list:
    print (f"({point.y}, {point.x}),")
# Out:
# (47.62406711673248, -122.35681812266914),
# (47.62184065259279, -122.35683403528067),
# (47.61927266845008, -122.35686022308631),
# (47.618524731799205, -122.35172435560875),
# (47.61851010471927, -122.34788339121029),
# (47.61848789863507, -122.342557910884),
# (47.61847057137016, -122.33823428254003),
# (47.6184681046027, -122.33458024109375),
# (47.61843356523203, -122.33093744651318),
# (47.618432351908616, -122.32744161325273),
# (47.619132670865994, -122.32489053729934),
# (47.619847616701406, -122.3204823697378),
# (47.619877663252566, -122.31643578753274),
# (47.61990248672513, -122.31305416618729),
# (47.6204346404472, -122.31103339644437),
# (47.620424971958904, -122.30752909590014),
# (47.62014794350839, -122.30318990780103),
# (47.621100526956845, -122.29957486573532),
# (47.6224924206519, -122.29752539204864),
# (47.62002404135477, -122.29620681485034),
# (47.61624662954705, -122.29627498205727),
# (47.61273578482247, -122.29631819477444),
# (47.609803380341724, -122.29634928199616),
# (47.607677951488334, -122.29644359996583),
# (47.603994484137054, -122.29690358727974),
# (47.60173339010839, -122.2981859671602),
# (47.601265468769064, -122.30236471920378),
# (47.599223165390924, -122.30143547932501),
# (47.59898741750448, -122.29753708019398),
# (47.595305600456264, -122.29776185013083),
# (47.590028050915215, -122.29763769913612),
# (47.58800072598081, -122.29820484208541),
# (47.584263263793446, -122.29825773562735),
# (47.58100692054131, -122.29693415058638),
# (47.5775954567337, -122.2971381206147),
