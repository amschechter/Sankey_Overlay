# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.path import Path
from matplotlib.patches import PathPatch

from shapely.geometry import Polygon

import geopandas as gpd

import folium

from pyproj import Transformer

# %%
# WGS84 (lat/lon) <-> Web Mercator (meters)
to_3857 = Transformer.from_crs("EPSG:4326", "EPSG:3857", always_xy=True)
to_4326 = Transformer.from_crs("EPSG:3857", "EPSG:4326", always_xy=True)

def project_to_3857(lon, lat):
    return to_3857.transform(lon, lat)

def project_to_4326(x, y):
    return to_4326.transform(x, y)

# %%
def bezier_curve(start, control1, control2, end, n=100):
    """Generate a cubic Bezier curve."""
    t = np.linspace(0, 1, n)[:, None]  # shape (n, 1)
    start, control1, control2, end = map(np.array, [start, control1, control2, end])
    curve = (
        (1 - t)**3 * start
        + 3 * (1 - t)**2 * t * control1
        + 3 * (1 - t) * t**2 * control2
        + t**3 * end
    )
    return curve

# %%
def perp(v):
    return np.array([-v[1], v[0]])  # rotate 90° left


def flow_patch_geo(
    start_ll, end_ll,
    start_width,
    end_width,
    color,
    bend=0.1,
    curvature=50,
    inherit_normal=None,
    start_offset_m=0,
    end_offset_m=0,
    offset_direction="left",  # "left", "right", or np.array([x,y])

):
    """
    Construct a flow patch polygon where width and offsets are expressed in meters.

    start_offset_m / end_offset_m:
        Lateral shift (in meters) applied to the start/end points.
        Positive values shift to the chosen offset_direction.
    """

    # ---- Project lat/lon to EPSG:3857 meters ----
    start = np.array(project_to_3857(*start_ll))
    end   = np.array(project_to_3857(*end_ll))

    # Direction vector in meters
    d = end - start
    d_norm = np.linalg.norm(d)
    if d_norm == 0:
        raise ValueError("Start and end coordinates are identical; cannot compute direction.")

    ud = d / d_norm  # unit direction

    # Determine base normal
    if inherit_normal is None:
        n = perp(ud)
        n = n / np.linalg.norm(n)
    else:
        n = inherit_normal / np.linalg.norm(inherit_normal)

    # ---- Determine offset direction ----
    if isinstance(offset_direction, str):
        if offset_direction == "left":
            offset_n = n
        elif offset_direction == "right":
            offset_n = -n
        else:
            raise ValueError("offset_direction must be 'left', 'right', or a 2D vector.")
    else:
        # custom vector
        offset_n = np.array(offset_direction)
        offset_n = offset_n / np.linalg.norm(offset_n)

    # ---- Apply lateral offsets in meters ----
    start = start + offset_n * start_offset_m
    end   = end   + offset_n * end_offset_m

    # ---- Bézier control points in meters ----
    ctrl1 = start + d * bend + n * curvature
    ctrl2 = end   - d * bend + n * curvature

    # ---- Construct edges with width in meters ----
    sw = start_width / 2.0
    ew = end_width   / 2.0

    top = bezier_curve(
        start + n * sw,
        ctrl1 + n * sw,
        ctrl2 + n * ew,
        end   + n * ew
    )

    bottom = bezier_curve(
        end   - n * ew,
        ctrl2 - n * ew,
        ctrl1 - n * sw,
        start - n * sw
    )

    # Combine and close
    verts = np.vstack([top, bottom, top[0]])

    # Convert back to lat/lon
    verts_ll = [project_to_4326(x, y) for x, y in verts]

    width_and_color = [start_width, color]

    #return Polygon(verts_ll), n, width_and_color
    return Polygon(verts_ll), width_and_color

# %%
## list of lat longs 
'''
[(47.683729430644014, -122.34433918947462),
 (47.687259045590366, -122.34435249866571),
 (47.69108874059965, -122.34437859849116),
 (47.69480518468918, -122.34442577658399),
 (47.698157590581, -122.34452735842333),
 (47.70168220570689, -122.3445039810145),
 (47.70544935545624, -122.34455265309363),
 (47.71273742733618, -122.34473223501618),
 (47.7194691813143, -122.34484691221628),
 (47.723740055102255, -122.34489403611852)]

'''
# Out:
# '\n[(47.683729430644014, -122.34433918947462),\n (47.687259045590366, -122.34435249866571),\n (47.69108874059965, -122.34437859849116),\n (47.69480518468918, -122.34442577658399),\n (47.698157590581, -122.34452735842333),\n (47.70168220570689, -122.3445039810145),\n (47.70544935545624, -122.34455265309363),\n (47.71273742733618, -122.34473223501618),\n (47.7194691813143, -122.34484691221628),\n (47.723740055102255, -122.34489403611852)]\n\n'

# %%
## E line going from south to north
point_list = [
     (47.683729430644014, -122.34433918947462),
     (47.687259045590366, -122.34435249866571),
     (47.69108874059965, -122.34437859849116),
     (47.69480518468918, -122.34442577658399)
]

# %%
rider_numbers = {
    1: [5, 0], #5
    2: [3, 2], #6
    3: [2, 4]  #4
}

# %%
Starting_Y_Val = point_list[0][0]
Second_Y_Val = point_list[1][0]
Third_Y_Val = point_list[2][0]

Starting_X_Val = point_list[0][1]
Second_X_Val = point_list[1][1]
Third_X_Val = point_list[2][1]

# %%
polygon_list = []
width_and_color_list = []

# %%
point_list[0][0]
# Out:
# 47.683729430644014

# %%
def make_trunk_polygon(segment_num, width):
    X_Val_1 = point_list[segment_num][1]
    Y_Val_1 = point_list[segment_num][0]
    X_Val_2 = point_list[segment_num + 1][1]
    Y_Val_2 = point_list[segment_num + 1][0]
    trunk, width_and_color = flow_patch_geo(
        start_ll = (X_Val_1, Y_Val_1),
        end_ll = (X_Val_2, Y_Val_2),
        start_width=width,  # 40 meters
        end_width=width,     # 40 meters
        start_offset_m = 0,
        end_offset_m = 0,
        bend = 0.1,
        curvature = 0,
        color = 'cornflowerblue'
    )     
    
    polygon_list.append(trunk)
    width_and_color_list.append(width_and_color)

# %%
def make_boarding_polygon(segment_num, width):
    X_Val_1 = point_list[segment_num][1]
    Y_Val_1 = point_list[segment_num][0]
    X_Val_2 = point_list[segment_num + 1][1]
    Y_Val_2 = point_list[segment_num + 1][0]
    trunk, width_and_color = flow_patch_geo(
        start_ll = (X_Val_1, Y_Val_1),
        end_ll = (X_Val_2, Y_Val_2),
        start_width=width,  
        end_width=width,   
        start_offset_m = 150,    ## start offset should be large (2.5 * end offset?)
        end_offset_m = 50,    ## end offset should be trunk_width * 0.5 + boarding_width * 0.5
        bend = 0.1,
        curvature = 20,
        color = 'orange'
    )  

    polygon_list.append(trunk)
    width_and_color_list.append(width_and_color)

# %%
def make_alighting_polygon(segment_num, width):
    X_Val_1 = point_list[segment_num][1]
    Y_Val_1 = point_list[segment_num][0]
    X_Val_2 = point_list[segment_num + 1][1]
    Y_Val_2 = point_list[segment_num + 1][0]
    trunk, width_and_color = flow_patch_geo(
        start_ll = (X_Val_1, Y_Val_1),
        end_ll = (X_Val_2, Y_Val_2),
        start_width=width,  
        end_width=width,   
        start_offset_m = -50,    ## start offset should be trunk_width * 0.5 + boarding_width * 0.5
        end_offset_m = -150,    ## end offset should be large (2.5 * end offset?)
        bend = 0.1,
        curvature = -20,
        color = 'green'
    )  

    polygon_list.append(trunk)
    width_and_color_list.append(width_and_color)

# %%
make_trunk_polygon(0, 50)
make_trunk_polygon(1, 80)
make_trunk_polygon(2, 30)
make_boarding_polygon(0, 20)
make_boarding_polygon(1, 40)
make_boarding_polygon(2, 30)
make_alighting_polygon(1, 50)
make_alighting_polygon(2, 20)

# %%
width_and_color_list
# Out:
# [[50, 'cornflowerblue'],
#  [80, 'cornflowerblue'],
#  [30, 'cornflowerblue'],
#  [20, 'orange'],
#  [40, 'orange'],
#  [30, 'orange'],
#  [50, 'green'],
#  [20, 'green']]

# %%
trunk_1, width_and_color_1 = flow_patch_geo(
    start_ll = (Starting_X_Val, Starting_Y_Val),
    end_ll = (Second_X_Val, Second_Y_Val),
    start_width=50,  # 40 meters
    end_width=50,     # 40 meters
    bend = 0.1,
    curvature = 0,
    color = 'cornflowerblue'
)

entry_branch_1, width_and_color_2 = flow_patch_geo(
    #start_ll=(40.1, -73.9),
    #end_ll=(40.2, -73.95),
    start_ll = (Starting_X_Val, Starting_Y_Val),
    end_ll = (Second_X_Val, Second_Y_Val),
    start_width=30,
    end_width=30,
    start_offset_m = 120,  # move start 10 m to the left
    end_offset_m = 40,
    curvature=20,
    color = 'orange'
)

trunk_2, width_and_color_3 = flow_patch_geo(
    start_ll = (Second_X_Val, Second_Y_Val),
    end_ll = (Third_X_Val, Third_Y_Val),
    start_width=60,  # 40 meters
    end_width=60,     # 40 meters
    bend = 0.1,
    curvature = 0,
    start_offset_m = 25,
    color = 'cornflowerblue'
)

exit_branch_2, width_and_color_4 = flow_patch_geo(
    start_ll = (Second_X_Val, Second_Y_Val),
    end_ll = (Third_X_Val, Third_Y_Val),
    start_width=20,
    end_width=20,
    start_offset_m = -15,  # move start XX meters to the left
    end_offset_m = -80,
    curvature = -10,
    color = 'green'
)

entry_branch_2, width_and_color_5 = flow_patch_geo(
    start_ll = (Second_X_Val, Second_Y_Val),
    end_ll = (Third_X_Val, Third_Y_Val),
    start_width=20,
    end_width=20,
    start_offset_m = 110,  # move start XX meters to the left
    end_offset_m = 40,
    curvature=20,
    color = 'orange'

)



#polygon_list = [trunk_1, entry_branch_1, trunk_2, exit_branch_2, entry_branch_2]
#width_and_color_list = [width_and_color_1, width_and_color_2, width_and_color_3, width_and_color_4, width_and_color_5]

#polygon_list = [trunk_poly, entry_branch_poly, trunk_poly_2, exit_branch_poly]

# %%
#colors = ['cornflowerblue', 'orange', 'cornflowerblue', 'green']


m = folium.Map(location=[47.683729430644014, -122.34433918947462], zoom_start=14)



for poly, width_and_color in zip(polygon_list, width_and_color_list):
    color = width_and_color[1]
    
    tt = (f"Riders = {width_and_color[0] / 10}") ## figure out how to get values from the method calls
    folium.GeoJson(
        poly,
        style_function=lambda _, col = color: {
        #style_function=lambda _, col = : {
            "fillColor": col,
            "color": col,
            "weight": 1,
            "fillOpacity": 0.7
        }, 
        tooltip = tt
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2558cd569f64ae97a4cb3dd98b99d608 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2558cd569f64ae97a4cb3dd98b99d608&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2558cd569f64ae97a4cb3dd98b99d608 = L.map(
#                 &quot;map_2558cd569f64ae97a4cb3dd98b99d608&quot;,
#                 {
#                     center: [47.683729430644014, -122.34433918947462],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d3aaad3cfc9267e3ef3e7cd31a507a0c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d3aaad3cfc9267e3ef3e7cd31a507a0c.addTo(map_2558cd569f64ae97a4cb3dd98b99d608);
#
#
#         function geo_json_26b66689740a748f09136ed3e9764dfd_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;cornflowerblue&quot;, &quot;fillColor&quot;: &quot;cornflowerblue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_26b66689740a748f09136ed3e9764dfd_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_26b66689740a748f09136ed3e9764dfd = L.geoJson(null, {
#                 onEachFeature: geo_json_26b66689740a748f09136ed3e9764dfd_onEachFeature,
#
#                 style: geo_json_26b66689740a748f09136ed3e9764dfd_styler,
#             ...{
# }
#         });
#
#         function geo_json_26b66689740a748f09136ed3e9764dfd_add (data) {
#             geo_json_26b66689740a748f09136ed3e9764dfd
#                 .addData(data);
#         }
#             geo_json_26b66689740a748f09136ed3e9764dfd_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122